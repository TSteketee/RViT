# %%
import torch
from fasterRvitnew import RViT
from torchvision.models import swin_v2_b, Swin_V2_B_Weights, vit_b_16, ViT_B_16_Weights

# %%
swin_model = swin_v2_b(weights=Swin_V2_B_Weights.IMAGENET1K_V1, num_classes=1000)
vit_model = vit_b_16(weights=ViT_B_16_Weights.DEFAULT, num_classes=1000)


model = RViT(
    vit_model,
    num_classes=80,
    image_min_size=224,
    image_max_size=224,
    anchor_sizes=(32, 64, 128, 256, 512),
    aspect_ratios=(0.5, 1.0, 2.0),
    rpn_depth=2,
    swin_fpn=True,
    swin_embed_dim=512,
)
model.eval()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 5
#       1 swin_model = swin_v2_b(weights=Swin_V2_B_Weights.IMAGENET1K_V1, num_classes=1000)
#       2 vit_model = vit_b_16(weights=ViT_B_16_Weights.DEFAULT, num_classes=1000)
# ----> 5 model = RViT(
#       6     vit_model,
#       7     num_classes=80,
#       8     image_min_size=224,
#       9     image_max_size=224,
#      10     anchor_sizes=(32, 64, 128, 256, 512),
#      11     aspect_ratios=(0.5, 1.0, 2.0),
#      12     rpn_depth=2,
#      13     swin_fpn=True,
#      14     swin_embed_dim=512,
#      15 )
#      16 model.eval()
#
# TypeError: RViT.__init__() got an unexpected keyword argument 'swin_fpn'

# %%
y = model(torch.rand(1, 3, 800, 800))
print(y)
# Out:
# [{'boxes': tensor([], size=(0, 4), grad_fn=<StackBackward0>), 'labels': tensor([], dtype=torch.int64), 'scores': tensor([], grad_fn=<IndexBackward0>)}]

# %%
swin_model
# Out:
# SwinTransformer(
#   (features): Sequential(
#     (0): Sequential(
#       (0): Conv2d(3, 128, kernel_size=(4, 4), stride=(4, 4))
#       (1): Permute()
#       (2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     )
#     (1): Sequential(
#       (0): SwinTransformerBlockV2(
#         (norm1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (attn): ShiftedWindowAttentionV2(
#           (qkv): Linear(in_features=128, out_features=384, bias=True)
#           (proj): Linear(in_features=128, out_features=128, bias=True)
#           (cpb_mlp): Sequential(
#             (0): Linear(in_features=2, out_features=512, bias=True)
#             (1): ReLU(inplace=True)
#             (2): Linear(in_features=512, out_features=4, bias=False)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.0, mode=row)
#         (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
# ...

# %%
anchor_sizes=(32, 64, 128, 256, 512)
# turn a tuple of 5 ints to a tuple of 5 tuples of 1 int
anchor_sizes
# Out:
# ((32,), (64,), (128,), (256,), (512,))
